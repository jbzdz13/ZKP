# %%
import hashlib
from typing import List, Dict, Any
from datetime import datetime
from pymongo import MongoClient
import secrets

# %%
# ==============================
# CONFIGURATION
# ==============================

MONGO_URI = "YOUR_MONGODB_ATLAS_CONNECTION_STRING"
DATABASE_NAME = "merkle_zkp_db"
COLLECTION_NAME = "verifications"

# Attempt to connect to MongoDB Atlas
# If connection fails, use in-memory fallback
client = None
collection = None
use_fallback = False
fallback_data = []

try:
    client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
    client.admin.command('ping')  # Test connection
    db = client[DATABASE_NAME]
    collection = db[COLLECTION_NAME]
    print("Connected to MongoDB Atlas ✅")
except Exception as e:
    print(f"⚠️ MongoDB connection failed: {str(e)[:100]}")
    print("Using in-memory fallback database for demo purposes")
    use_fallback = True
    print("To use MongoDB Atlas, update MONGO_URI with your connection string from https://www.mongodb.com/cloud/atlas")
# Out:
# Connected to MongoDB Atlas ✅

# %%
def sha256(data: bytes) -> str:
    return hashlib.sha256(data).hexdigest()

def hash_string(value: str) -> str:
    return sha256(value.encode("utf-8"))

# %%
def generate_merkle_root(leaves: List[str]) -> str:
    if not leaves:
        raise ValueError("Leaf list cannot be empty")

    level = leaves[:]
    while len(level) > 1:
        next_level = []
        for i in range(0, len(level), 2):
            left = level[i]
            right = level[i + 1] if i + 1 < len(level) else left
            combined_hash = sha256((left + right).encode())
            next_level.append(combined_hash)
        level = next_level
    return level[0]

def verify_merkle_root(leaves: List[str], expected_root: str) -> bool:
    return generate_merkle_root(leaves) == expected_root

# %%
# ==============================
# GENERIC ZERO-KNOWLEDGE PROOF
# ==============================

# This ZKP is simplified for demonstration.
# It proves that you "know a secret" (merkle_root) without revealing it.

def generate_zkp(secret: str) -> Dict[str, str]:
    """
    Generate a dummy zero-knowledge proof for a secret
    """
    nonce = secrets.token_hex(16)
    commitment = sha256((secret + nonce).encode())
    proof = {
        "commitment": commitment,
        "nonce": nonce
    }
    return proof

def verify_zkp(secret: str, proof: Dict[str, str]) -> bool:
    """
    Verify dummy zero-knowledge proof
    """
    expected_commitment = sha256((secret + proof["nonce"]).encode())
    return expected_commitment == proof["commitment"]

# %%
def store_record(
    user_id: str,
    merkle_root: str,
    file_count: int,
    zkp_proof: Dict[str, str]
) -> Dict[str, Any]:

    record = {
        "user_id": user_id,
        "merkle_root": merkle_root,
        "file_count": file_count,
        "zkp_proof": zkp_proof,
        "timestamp": datetime.utcnow()
    }

    if use_fallback:
        fallback_data.append(record)
    else:
        collection.insert_one(record)
    
    return record

def get_user_history(user_id: str):
    if use_fallback:
        return [r for r in fallback_data if r["user_id"] == user_id]
    else:
        return list(collection.find({"user_id": user_id}, {"_id": 0}))

# %%
# 1️⃣ Simulated file hashing
files = ["file1.pdf", "file2.pdf", "file3.pdf"]
file_hashes = [hash_string(f) for f in files]

print("File Hashes:")
print(file_hashes)

# 2️⃣ Generate Merkle Root
merkle_root = generate_merkle_root(file_hashes)
print("\nMerkle Root:")
print(merkle_root)

# 3️⃣ Generate ZKP
zkp_proof = generate_zkp(merkle_root)

# 4️⃣ Verify ZKP before storing
if verify_zkp(merkle_root, zkp_proof):
    print("\nZKP Verified ✅")
else:
    raise Exception("ZKP Failed ❌")

# 5️⃣ Store in MongoDB Atlas
record = store_record(
    user_id="user_123",
    merkle_root=merkle_root,
    file_count=len(file_hashes),
    zkp_proof=zkp_proof
)

print("\nStored Record:")
print(record)

# 6️⃣ Verify Merkle Root
print("\nMerkle Root Valid:", verify_merkle_root(file_hashes, merkle_root))

# 7️⃣ Fetch History
history = get_user_history("user_123")
print("\nUser History:")
print(history)
# Out:
# File Hashes:
# ['2bc7f5da08ebda7d761bbfd4bed3c6c2718492aa4e0e2063786219bc7687a40c', 'aa78d5a5c01ef76017576055d20f3007093aa9ba583655f0b236f7506e6bfd60', 'fe3a0126360ed6fcd6bec4f663d404d9791f1b529c7d239024451d57bfd8333a']
#
# Merkle Root:
# 0a75c57d690d637366bbf3706259f0393dbed6c86eab9e53a56b30062eebd283
#
# ZKP Verified ✅
# C:\Users\USER\AppData\Local\Temp\ipykernel_18644\1886946449.py:13: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow()
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[7], line 23
#      20     raise Exception("ZKP Failed ❌")
#      22 # 5️⃣ Store in MongoDB Atlas
# ---> 23 record = store_record(
#      24     user_id="user_123",
#      25     merkle_root=merkle_root,
#      26     file_count=len(file_hashes),
#      27     zkp_proof=zkp_proof
#      28 )
#      30 print("\nStored Record:")
#      31 print(record)
#
# Cell In[6], line 16, in store_record(user_id, merkle_root, file_count, zkp_proof)
#       1 def store_record(
#       2     user_id: str,
#       3     merkle_root: str,
#       4     file_count: int,
#       5     zkp_proof: Dict[str, str]
#       6 ) -> Dict[str, Any]:
#       8     record = {
#       9         "user_id": user_id,
#      10         "merkle_root": merkle_root,
#    (...)     13         "timestamp": datetime.utcnow()
#      14     }
# ---> 16     collection.insert_one(record)
#      17     return record
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)    826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\mongo_client.py:2083, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2069 """Execute an operation with consecutive retries if possible
#    2070
#    2071 Returns func()'s return value on success. On error retries the same
#    (...)   2080 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2081 """
#    2082 with self._tmp_session(session) as s:
# -> 2083     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\mongo_client.py:2873, in _ClientConnectionRetryable._write(self)
#    2871 max_wire_version = 0
#    2872 is_mongos = False
# -> 2873 self._server = self._get_server()
#    2874 with self._client._checkout(self._server, self._session) as conn:
#    2875     max_wire_version = conn.max_wire_version
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)    425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)    400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File c:\Users\USER\Desktop\myjavafxproject\VScode SE\Lib\site-packages\pymongo\synchronous\topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: your_mongodb_atlas_connection_string:27017: [Errno 11001] getaddrinfo failed (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69971fb0cdc7b79fa1ab9a8c, topology_type: Unknown, servers: [<ServerDescription ('your_mongodb_atlas_connection_string', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('your_mongodb_atlas_connection_string:27017: [Errno 11001] getaddrinfo failed (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
